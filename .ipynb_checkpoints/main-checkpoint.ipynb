# %%
import pandas as pd
from tqdm import tqdm

# %%
data = pd.read_csv('D:/Ultimate USA/Data Science/Data analytics/Twitter sentiment analysis/archive (4)/training.1600000.processed.noemoticon.csv', encoding='UTF-8', encoding_errors='ignore')
data = data.iloc[:100000,:]
data.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 data = pd.read_csv('D:/Ultimate USA/Data Science/Data analytics/Twitter sentiment analysis/archive (4)/training.1600000.processed.noemoticon.csv', encoding='UTF-8', encoding_errors='ignore')
#       2 data = data.iloc[:100000,:]
#       3 data.head()
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\io\parsers\readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\io\parsers\readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\_libs\parsers.pyx:812, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\_libs\parsers.pyx:873, in pandas._libs.parsers.TextReader._read_rows()
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\_libs\parsers.pyx:848, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\_libs\parsers.pyx:859, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\_libs\parsers.pyx:2025, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
data.columns = ['target','id','date','flag','user','text']

# %%
data.head()
# Out:
#    target          id                          date      flag           user
# 0       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton  \
# 1       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4       0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                 text
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
data.drop(columns=['id','date','flag','user'], inplace=True)
data.head()
# Out:
#    target                                               text
# 0       0  is upset that he can't update his Facebook by ...
# 1       0  @Kenichan I dived many times for the ball. Man...
# 2       0    my whole body feels itchy and like its on fire
# 3       0  @nationwideclass no, it's not behaving at all....
# 4       0                      @Kwesidei not the whole crew

# %%
import re

def clean_text(text):
    # remove words starting with @ symbol
    text = re.sub(r'@\w+\s?', '', text)
    
    # remove non-alphabetic characters and convert to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text).lower()
    
    # remove unnecessary whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

def clean_data(data):
    # initialize progress bar
    tqdm.pandas()
    
    # apply clean_text function to each sentence in text column
    data['clean_text'] = data['text'].progress_apply(clean_text)
    
    return data

clean_data(data)
# Out:
# 100%|██████████| 100000/100000 [00:00<00:00, 106855.86it/s]
#        target                                               text
# 0           0  is upset that he can't update his Facebook by ...  \
# 1           0  @Kenichan I dived many times for the ball. Man...
# 2           0    my whole body feels itchy and like its on fire
# 3           0  @nationwideclass no, it's not behaving at all....
# 4           0                      @Kwesidei not the whole crew
# ...       ...                                                ...
# 99995       0  looks like my routers broke  more tweets from ...
# 99996       0  i really dont want to be in college right now....
# 99997       0                        @flossa  *offers you pepto*
# 99998       0  @JosieHobo I WOULD SOOOOO BE THERE IF I DIDN'T...
# 99999       0  OMG, I just moisturised and my legs are BURNIN...
#
#                                               clean_text
# 0      is upset that he cant update his facebook by t...
# 1      i dived many times for the ball managed to sav...
# 2         my whole body feels itchy and like its on fire
# 3      no its not behaving at all im mad why am i her...
# 4                                     not the whole crew
# ...                                                  ...
# 99995  looks like my routers broke more tweets from m...
# 99996  i really dont want to be in college right now ...
# 99997                                   offers you pepto
# 99998  i would sooooo be there if i didnt have revisi...
# 99999  omg i just moisturised and my legs are burning...
#
# [100000 rows x 3 columns]

# %%
from transformers import AutoTokenizer

def tokenize_data(data, model_name):
    # load pre-trained tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    tqdm.pandas()
    # tokenize each sentence in clean_text column
    data['tokens'] = data['clean_text'].progress_apply(lambda x: tokenizer.encode(x, add_special_tokens=True))
    vocab_dict = tokenizer.get_vocab()
    return data, vocab_dict, tokenizer
model_name = 'bert-base-uncased'
tokenized_data, vocab_dict, tokenizer = tokenize_data(data, model_name)
# Out:
# 100%|██████████| 100000/100000 [00:14<00:00, 6674.69it/s]

# %%
len(vocab_dict)
# Out:
# 30522

# %%
max_ = 0
for i in data['tokens'].values:
    if len(i) > max_:
        max_ = len(i)
max_
# Out:
# 63

# %%
import numpy as np

def pad_tokens(data, max_length):
    """
    Pads the tokenized sentences in the 'tokens' column of the input DataFrame to a fixed length.
    
    Args:
        data (pandas.DataFrame): The input DataFrame with the 'tokens' column containing the tokenized sentences.
        max_length (int): The maximum length of the padded sentences.
    
    Returns:
        np.ndarray: A 2D NumPy array of shape (num_sentences, max_length) containing the padded token IDs.
    """
    # Get the tokenized sentences as a list
    tokenized_sentences = data['tokens'].tolist()
    
    # Initialize an empty array to hold the padded token IDs
    padded_tokens = np.zeros((len(tokenized_sentences), max_length))
    
    # Pad each sentence with zeros to the desired length and store in the padded_tokens array
    for i, tokens in enumerate(tokenized_sentences):
        padded_tokens[i, :min(len(tokens), max_length)] = tokens[:max_length]
    
    return padded_tokens
padded_tokens = pad_tokens(data, max_)

# %%
data['padded_tokens'] = pd.Series(padded_tokens)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 data['padded_tokens'] = pd.Series(padded_tokens)
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\core\series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     507         data = data.copy()
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#     512     if manager == "block":
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\core\construction.py:607, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604             subarr = cast(np.ndarray, subarr)
#     605             subarr = maybe_infer_to_datetimelike(subarr)
# --> 607 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     609 if isinstance(subarr, np.ndarray):
#     610     # at this point we should have dtype be None or subarr.dtype == dtype
#     611     dtype = cast(np.dtype, dtype)
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\pandas\core\construction.py:666, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     664     if allow_2d:
#     665         return result
# --> 666     raise ValueError(
#     667         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     668     )
#     669 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     670     # i.e. PandasDtype("O")
#     672     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (100000, 63) instead

# %%
import spacy

def perform_ner(data):
    nlp = spacy.load('en_core_web_sm')
    entities = []
    for doc in nlp.pipe(data['clean_text']):
        entity_list = [(ent.text, ent.label_) for ent in doc.ents]
        entities.append(entity_list)
    data['entities'] = entities
    return data

# print(perform_ner(data))

# %%
# data['entities']
# Out:
# 0                          [(today, DATE)]
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
#                        ...
# 9995                                    []
# 9996                                    []
# 9997                                    []
# 9998                                    []
# 9999    [(yesterday, DATE), (today, DATE)]
# Name: entities, Length: 10000, dtype: object

# %%
# import nltk
# from nltk.probability import FreqDist

# # Tokenize the clean_text column and flatten the list
# tokens = data['clean_text'].apply(nltk.word_tokenize).sum()

# # Create frequency distribution
# fdist = FreqDist(tokens)

# %%
# import matplotlib.pyplot as plt

# # Set number of top words to display
# n = 20

# # Create bar chart of top n most common words
# plt.figure(figsize=(12,6))
# fdist.plot(n, cumulative=False)
# plt.title(f'Top {n} Most Common Words')
# plt.xlabel('Words')
# plt.ylabel('Frequency')
# plt.show()

# %%
# from wordcloud import WordCloud

# # Create word cloud visualization
# wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(fdist)

# # Display the word cloud visualization
# plt.figure(figsize=(12, 8))
# plt.imshow(wordcloud)
# plt.axis("off")
# plt.tight_layout(pad=0)
# plt.show()

# %%
# import gensim
# from gensim.corpora import Dictionary
# from gensim.models.ldamodel import LdaModel
# from gensim.models.coherencemodel import CoherenceModel

# # tokenize the clean_text column
# data['tokens_for_topic'] = data['clean_text'].apply(lambda x: x.split())

# # create a dictionary from the tokenized text
# dictionary = Dictionary(data['tokens_for_topic'])

# # convert the tokenized text to bag-of-words representation
# bow_corpus = [dictionary.doc2bow(doc) for doc in data['tokens_for_topic']]

# # build LDA model
# lda_model = LdaModel(
#     corpus=bow_corpus,
#     id2word=dictionary,
#     num_topics=10,
#     random_state=42,
#     passes=10,
#     per_word_topics=True
# )

# # print topics and their top words
# for idx, topic in lda_model.print_topics(-1):
#     print(f'Topic: {idx}\nWords: {topic}\n')
    
# # compute coherence score to evaluate the model
# coherence_model_lda = CoherenceModel(
#     model=lda_model,
#     texts=data['tokens_for_topic'],
#     dictionary=dictionary,
#     coherence='c_v'
# )
# coherence_lda = coherence_model_lda.get_coherence()
# print(f'Coherence Score: {coherence_lda}')
# Out:
# Topic: 0
# Words: 0.079*"to" + 0.041*"the" + 0.023*"work" + 0.022*"and" + 0.019*"is" + 0.018*"of" + 0.016*"a" + 0.016*"in" + 0.015*"going" + 0.013*"i"
#
# Topic: 1
# Words: 0.036*"my" + 0.035*"is" + 0.024*"she" + 0.023*"her" + 0.012*"hurts" + 0.010*"has" + 0.009*"are" + 0.009*"being" + 0.008*"throat" + 0.008*"head"
#
# Topic: 2
# Words: 0.021*"please" + 0.011*"break" + 0.010*"sooo" + 0.009*"x" + 0.007*"theyre" + 0.007*"okay" + 0.007*"amp" + 0.007*"fucking" + 0.006*"im" + 0.006*"spring"
#
# Topic: 3
# Words: 0.014*"pm" + 0.013*"fuck" + 0.012*"arent" + 0.010*"definitely" + 0.009*"ouch" + 0.008*"freezing" + 0.008*"la" + 0.007*"yall" + 0.007*"driving" + 0.007*"nearly"
#
# Topic: 4
# Words: 0.029*"of" + 0.025*"the" + 0.023*"my" + 0.015*"friends" + 0.013*"is" + 0.008*"a" + 0.008*"miss" + 0.008*"food" + 0.008*"too" + 0.008*"in"
#
# Topic: 5
# Words: 0.045*"a" + 0.024*"for" + 0.024*"and" + 0.024*"my" + 0.023*"is" + 0.019*"the" + 0.017*"not" + 0.016*"im" + 0.016*"at" + 0.015*"up"
#
# Topic: 6
# Words: 0.076*"the" + 0.032*"in" + 0.030*"my" + 0.022*"is" + 0.017*"on" + 0.015*"for" + 0.013*"just" + 0.013*"of" + 0.013*"and" + 0.009*"not"
#
# Topic: 7
# Words: 0.055*"me" + 0.015*"im" + 0.013*"his" + 0.012*"my" + 0.012*"and" + 0.012*"is" + 0.011*"sad" + 0.008*"making" + 0.008*"tell" + 0.007*"in"
#
# Topic: 8
# Words: 0.098*"i" + 0.041*"to" + 0.022*"it" + 0.022*"you" + 0.015*"have" + 0.015*"the" + 0.014*"a" + 0.014*"but" + 0.013*"that" + 0.013*"my"
#
# Topic: 9
# Words: 0.017*"til" + 0.010*"argh" + 0.010*"bring" + 0.010*"hahaha" + 0.009*"tummy" + 0.008*"traffic" + 0.008*"disappointed" + 0.007*"usual" + 0.007*"c" + 0.006*"asked"
#
# Coherence Score: 0.4406616134041519

# %%
data.head()
# Out:
#    target                                               text
# 0       0  is upset that he can't update his Facebook by ...  \
# 1       0  @Kenichan I dived many times for the ball. Man...
# 2       0    my whole body feels itchy and like its on fire
# 3       0  @nationwideclass no, it's not behaving at all....
# 4       0                      @Kwesidei not the whole crew
#
#                                           clean_text
# 0  is upset that he cant update his facebook by t...  \
# 1  i dived many times for the ball managed to sav...
# 2     my whole body feels itchy and like its on fire
# 3  no its not behaving at all im mad why am i her...
# 4                                 not the whole crew
#
#                                               tokens         entities
# 0  [101, 2003, 6314, 2008, 2002, 2064, 2102, 1065...  [(today, DATE)]  \
# 1  [101, 1045, 11529, 2094, 2116, 2335, 2005, 199...               []
# 2  [101, 2026, 2878, 2303, 5683, 2009, 11714, 199...               []
# 3  [101, 2053, 2049, 2025, 2022, 3270, 6455, 2012...               []
# 4                 [101, 2025, 1996, 2878, 3626, 102]               []
#
#                                     tokens_for_topic
# 0  [is, upset, that, he, cant, update, his, faceb...
# 1  [i, dived, many, times, for, the, ball, manage...
# 2  [my, whole, body, feels, itchy, and, like, its...
# 3  [no, its, not, behaving, at, all, im, mad, why...
# 4                            [not, the, whole, crew]

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from keras_nlp import get_model, get_optimizer
#       2 from keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D
#       3 from tensorflow import keras
#
# ImportError: cannot import name 'get_model' from 'keras_nlp' (d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras_nlp\__init__.py)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Embedding, Dropout, SpatialDropout1D, MultiHeadAttention, LayerNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences

def build_transformer_model(num_heads, feed_forward_dim, num_layers, max_seq_length, vocab_size, embedding_dim):
    # Define the input layer
    inputs = Input(shape=(max_seq_length,), dtype=tf.int32)

    # Define the embedding layer
    embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_seq_length)(inputs)
    embedding_layer = SpatialDropout1D(0.2)(embedding_layer)

    # Define the transformer layers
    transformer_layers = []
    for i in range(num_layers):
        transformer_layer = MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim, dropout=0.2)(embedding_layer, embedding_layer)
        transformer_layer = Dropout(0.2)(transformer_layer)
        transformer_layer = LayerNormalization(epsilon=1e-6)(transformer_layer)
        transformer_layer = Dense(feed_forward_dim, activation='relu')(transformer_layer)
        transformer_layer = Dense(embedding_dim)(transformer_layer)
        transformer_layer = Dropout(0.2)(transformer_layer)
        transformer_layer = LayerNormalization(epsilon=1e-6)(transformer_layer)
        transformer_layers.append(transformer_layer)
    transformer_output = tf.keras.layers.concatenate(transformer_layers)

    # Define the output layer
    output_layer = Dense(3, activation='softmax')(transformer_output)

    # Create the model
    model = Model(inputs=inputs, outputs=output_layer)

    # Compile the model
    optimizer = Adam(lr=0.00001)
    model.compile(loss='sparse_categorical_crossentropy ', optimizer=optimizer, metrics=['accuracy'])

    return model

# %%
data['tokens']
# Out:
# 0        [101, 2003, 6314, 2008, 2002, 2064, 2102, 1065...
# 1        [101, 1045, 11529, 2094, 2116, 2335, 2005, 199...
# 2        [101, 2026, 2878, 2303, 5683, 2009, 11714, 199...
# 3        [101, 2053, 2049, 2025, 2022, 3270, 6455, 2012...
# 4                       [101, 2025, 1996, 2878, 3626, 102]
#                                ...
# 99995    [101, 3504, 2066, 2026, 2799, 2869, 3631, 2062...
# 99996    [101, 1045, 2428, 2123, 2102, 2215, 2000, 2022...
# 99997                  [101, 4107, 2017, 27233, 3406, 102]
# 99998    [101, 1045, 2052, 17111, 9541, 2080, 2022, 204...
# 99999    [101, 18168, 2290, 1045, 2074, 11052, 9496, 69...
# Name: tokens, Length: 100000, dtype: object

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping


# Split data into training and validation sets
X_train,X_val,y_train, y_val = train_test_split(padded_tokens,data['target'], test_size=0.2, random_state=42)

# Define parameters for the transformer model
num_heads = 8
feed_forward_dim = 512
num_layers = 4
max_seq_length = max_
vocab_size = len(vocab_dict)
embedding_dim = 64
print(type(X_train))
# Build the transformer model
model = build_transformer_model(num_heads, feed_forward_dim, num_layers, max_seq_length, vocab_size, embedding_dim)

# # Preprocess data

# print(type(X_train), X_train[0])
# # Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=3)
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=1, batch_size=128, callbacks=[early_stopping])
# Out:
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 25
#      20 # # Preprocess data
#      21
#      22 # print(type(X_train), X_train[0])
#      23 # # Train the model
#      24 early_stopping = EarlyStopping(monitor='val_loss', patience=3)
# ---> 25 model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=1, batch_size=128, callbacks=[early_stopping])
#
# File d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filermea7z1k.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\training.py", line 994, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\training.py", line 1052, in compute_loss
#         return self.compiled_loss(
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\compile_utils.py", line 240, in __call__
#         self.build(y_pred)
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\compile_utils.py", line 182, in build
#         self._losses = tf.nest.map_structure(
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\engine\compile_utils.py", line 353, in _get_loss_object
#         loss = losses_mod.get(loss)
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\losses.py", line 2649, in get
#         return deserialize(identifier)
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\losses.py", line 2603, in deserialize
#         return deserialize_keras_object(
#     File "d:\Ultimate USA\Data Science\Data analytics\Twitter sentiment analysis\venv\lib\site-packages\keras\utils\generic_utils.py", line 769, in deserialize_keras_object
#         raise ValueError(
#
#     ValueError: Unknown loss function: binary_crossentropy . Please ensure this object is passed to the `custom_objects` argument. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %%
def predict_sentiment(model, tokenizer, sentence):
    # Clean and preprocess the input sentence
    clean_sentence = clean_text(sentence)
    tokenized_sentence = tokenizer.encode(clean_sentence, add_special_tokens=True)
    padded_sentence = pad_sequences([tokenized_sentence], maxlen=max_, dtype="long", 
                                     value=0, truncating="post", padding="post")
    # Predict the sentiment label
    predicted_label = model.predict(padded_sentence)
    print(predicted_label)
    predicted_class = np.argmax(predicted_label, axis=1)
    print(predicted_class)
    sentiment_dict = {0: 'Negative', 2: 'Neutral', 4: 'Positive'}
    predicted_sentiment = sentiment_dict[predicted_class[0][0]]
    
    return predicted_sentiment

# %%
predict_sentiment(model,tokenizer,"I am fine")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# [[[1.34045622e-05]
#   [1.34045367e-05]
#   [1.34045622e-05]
#   [1.34045886e-05]
#   [1.34045240e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]
#   [1.34044985e-05]]]
# [[3]]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 predict_sentiment(model,tokenizer,"I am fine")
#
# Cell In[80], line 13, in predict_sentiment(model, tokenizer, sentence)
#      11 print(predicted_class)
#      12 sentiment_dict = {0: 'Negative', 2: 'Neutral', 4: 'Positive'}
# ---> 13 predicted_sentiment = sentiment_dict[predicted_class[0][0]]
#      15 return predicted_sentiment
#
# KeyError: 3

# %%
import tensorflow as tf
